# %%
import os
os.chdir("C:\\Users\\Administrator\\Desktop\\Python Assignments\\DataSets")
os.getcwd()
# Out:
# 'C:\\Users\\Administrator\\Desktop\\Python Assignments\\DataSets'

# %%
import pandas as pd
import numpy as np
import math as m

# %%
store=pd.read_csv('Store.csv', sep=',', header=0, encoding="latin")

# %%
#•	How many unique cities are the orders being delivered to
len(store.City.unique())
# Out:
# 531

# %%
#•	What is the total quantity sold in the East Region?
new=store[store.Region=="East"]
len(new.Quantity)
# Out:
# 2848

# %%
#•	Find the sum of the quantity sold in the East Region
new=store[store.Region=="East"]
len(new.Quantity)
# Out:
# 2848

# %%
#•	In the south region sort the sales in decreasing order
new=store[store.Region=="South"]
new.sort_values(by='Sales',ascending='F')
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 2605    2606  CA-2011-112718  12/16/2011  12/21/2011  Standard Class
# 9382    9383  CA-2011-154158  12/23/2011  12/27/2011    Second Class
# 6597    6598  CA-2011-169257    6/6/2011   6/12/2011  Standard Class
# 7900    7901  CA-2014-128363   8/14/2014   8/19/2014  Standard Class
# 8317    8318  CA-2014-130904   4/12/2014   4/17/2014  Standard Class
# 4005    4006  US-2012-168732  12/10/2012  12/16/2012  Standard Class
# 5479    5480  CA-2011-101770   3/31/2011    4/4/2011  Standard Class
# 7311    7312  CA-2012-162761   10/9/2012  10/13/2012  Standard Class
# 3769    3770  CA-2011-153913  12/16/2011  12/20/2011    Second Class
# 5440    5441  US-2014-153633  11/14/2014  11/19/2014    Second Class
# 4878    4879  US-2013-131891   7/30/2013    8/1/2013     First Class
# 2779    2780  CA-2014-108322    5/1/2014    5/6/2014  Standard Class
# 8215    8216  CA-2012-120845   9/25/2012   10/2/2012  Standard Class
# ...

# %%
#•	Find the mean of quantity for every region
store.groupby('Region')['Quantity'].mean()
# Out:
# Region
# Central    3.779595
# East       3.728230
# South      3.832716
# West       3.829535
# Name: Quantity, dtype: float64

# %%
#•	Find the mean of sales for every category
store.groupby('Category')['Sales'].mean()
# Out:
# Category
# Furniture          349.834887
# Office Supplies    119.324101
# Technology         452.709276
# Name: Sales, dtype: float64

# %%
#•	Find the max, min, sum of sales and profit for every category
store.groupby("Category")[['Sales','Profit']].agg(['max','min','sum'])
# Out:
#                      Sales                        Profit             \
#                        max    min          sum       max        min
# Category
# Furniture         4416.174  1.892  741999.7953  1013.127 -1862.3124
# Office Supplies   9892.740  0.444  719047.0320  4946.370 -3701.8928
# Technology       22638.480  0.990  836154.0330  8399.976 -6599.9780
#
#
#                          sum
# Category
# Furniture         18451.2728
# Office Supplies  122490.8008
# Technology       145454.9481

# %%
#•	Find sum of sales and max profit for every segment
store.groupby("Segment").agg({'Sales':np.sum,'Profit':np.max})
# Out:
#                     Sales     Profit
# Segment
# Consumer     1.161401e+06  6719.9808
# Corporate    7.061464e+05  8399.9760
# Home Office  4.296531e+05  3919.9888

# %%
#•	For every segment find the mean of the discount
store.groupby("Segment")[['Discount']].agg(['mean'])
# Out:
#              Discount
#                  mean
# Segment
# Consumer     0.158141
# Corporate    0.158228
# Home Office  0.147128

# %%
#•	For every segment find the most profitable customers
#store.groupby(['Segment'])['Profit','Customer Name'].max()
store[['Profit','Customer Name']].loc[store.groupby(['Segment'])['Profit'].idxmax()]
#store.groupby(["Segment","Customer Name"])[["Profit"]].max()
# Out:
#          Profit Customer Name
# 8153  6719.9808  Raymond Buch
# 6826  8399.9760  Tamara Chand
# 2623  3919.9888  Tom Ashbrook

# %%
#•	What are the top 5 categories that give maximum profit?
store.groupby(['Category'])['Profit'].max()
# Out:
# Category
# Furniture          1013.127
# Office Supplies    4946.370
# Technology         8399.976
# Name: Profit, dtype: float64

# %%
#•	What is the Total Sales, Quantity, Discount, Profit across Total US.
store[store.Country=="United States"][['Sales','Quantity','Discount','Profit']].sum()
# Out:
# Sales       2.297201e+06
# Quantity    3.787300e+04
# Discount    1.561090e+03
# Profit      2.863970e+05
# dtype: float64

# %%
#•	How many times has it taken more than 5 days from placing an order to shipping
store['Ship Date']=pd.to_datetime(store['Ship Date'])
store['Order Date']=pd.to_datetime(store['Order Date'])
store['days']=store['Ship Date']-store['Order Date']
store[store.days>'5 days']
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 3          4  US-2012-108966 2012-10-11 2012-10-18  Standard Class
# 4          5  US-2012-108966 2012-10-11 2012-10-18  Standard Class
# 16        17  CA-2011-105893 2011-11-11 2011-11-18  Standard Class
# 53        54  CA-2013-105816 2013-12-12 2013-12-18  Standard Class
# 54        55  CA-2013-105816 2013-12-12 2013-12-18  Standard Class
# 62        63  CA-2012-135545 2012-11-24 2012-11-30  Standard Class
# 63        64  CA-2012-135545 2012-11-24 2012-11-30  Standard Class
# 64        65  CA-2012-135545 2012-11-24 2012-11-30  Standard Class
# 65        66  CA-2012-135545 2012-11-24 2012-11-30  Standard Class
# 72        73  US-2012-134026 2012-04-26 2012-05-02  Standard Class
# 73        74  US-2012-134026 2012-04-26 2012-05-02  Standard Class
# 74        75  US-2012-134026 2012-04-26 2012-05-02  Standard Class
# 86        87  CA-2014-155558 2014-10-27 2014-11-03  Standard Class
# ...

# %%
#•	Find the total number of orders in every category which has been shipped with a duration > 5 days
store.groupby("Category")
n=store[store.days>"5 days"]
len(n)
# Out:
# 1822

# %%
#•	What’s the percentage of items which has been shipped within 5 days

#days=store[store.days<"5 days"]

percent=sum(store['Ship Date']-store['Order Date']<="5 days")/len(store['Ship Date']-store['Order Date'])*100
percent
# Out:
# 81.76906143686212

# %%
store
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2013-152156 2013-11-09 2013-11-12    Second Class
# 1          2  CA-2013-152156 2013-11-09 2013-11-12    Second Class
# 2          3  CA-2013-138688 2013-06-13 2013-06-17    Second Class
# 3          4  US-2012-108966 2012-10-11 2012-10-18  Standard Class
# 4          5  US-2012-108966 2012-10-11 2012-10-18  Standard Class
# 5          6  CA-2011-115812 2011-06-09 2011-06-14  Standard Class
# 6          7  CA-2011-115812 2011-06-09 2011-06-14  Standard Class
# 7          8  CA-2011-115812 2011-06-09 2011-06-14  Standard Class
# 8          9  CA-2011-115812 2011-06-09 2011-06-14  Standard Class
# 9         10  CA-2011-115812 2011-06-09 2011-06-14  Standard Class
# 10        11  CA-2011-115812 2011-06-09 2011-06-14  Standard Class
# 11        12  CA-2011-115812 2011-06-09 2011-06-14  Standard Class
# 12        13  CA-2014-114412 2014-04-16 2014-04-21  Standard Class
# ...

# %%
#•	What’s the percentage of items which has been shipped after 5 days
percent=sum(store['Ship Date']-store['Order Date']>"5 days")/len(store['Ship Date']-store['Order Date'])*100
percent
# Out:
# 18.230938563137883
